# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
# from api_keys import weather_api_key

weather_api_key = "6cb990c73e89fb81dab285393417f0a8"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | pinega
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | nobres
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | qorveh
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | osakarovka
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | piacabucu
# Processing Record 15 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 1 | naze
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | korla
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | mantua
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | priekule
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | konstantinovka
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | omsukchan
# Processing Record 33 of Set 1 | saint-francois
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | wanparti
# Processing Record 37 of Set 1 | buin
# Processing Record 38 of Set 1 | yurginskoye
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | faya
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | hilo
# Processing Record 1 of Set 2 | tessalit
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | opuwo
# Processing Record 5 of Set 2 | hamilton
# Processing Record 6 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 2 | penukonda
# Processing Record 8 of Set 2 | kieta
# Processing Record 9 of Set 2 | santa cruz
# Processing Record 10 of Set 2 | prince rupert
# Processing Record 11 of Set 2 | margate
# Processing Record 12 of Set 2 | liverpool
# Processing Record 13 of Set 2 | comodoro rivadavia
# Processing Record 14 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 2 | altamira
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | tambo
# Processing Record 20 of Set 2 | huarmey
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record
of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | fairbanks
# Processing Record 47 of Set 3 | tado
# Processing Record 48 of Set 3 | poopo
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 0 of Set 4 | nirasaki
# Processing Record 1 of Set 4 | angra
# City not found. Skipping...
# Processing Record 2 of Set 4 | northam
# Processing Record 3 of Set 4 | yantal
# Processing Record 4 of Set 4 | san rafael
# Processing Record 5 of Set 4 | ola
# Processing Record 6 of Set 4 | nuuk
# Processing Record 7 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 4 | ondangwa
# Processing Record 9 of Set 4 | buraydah
# Processing Record 10 of Set 4 | saint-augustin
# Processing Record 11 of Set 4 | kiunga
# Processing Record 12 of Set 4 | skjervoy
# Processing Record 13 of Set 4 | raudeberg
# Processing Record 14 of Set 4 | tatishchevo
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | gweta
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | dawei
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | banda aceh
# Processing Record 22 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 4 | san quintin
# Processing Record 24 of Set 4 | rio grande
# Processing Record 25 of Set 4 | outjo
# Processing Record 26 of Set 4 | loiza
# Processing Record 27 of Set 4 | torit
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | puerto baquerizo moreno
# Processing Record 30 of Set 4 | castro
# Processing Record 31 of Set 4 | malpe
# Processing Record 32 of Set 4 | paamiut
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | motygino
# Processing Record 35 of Set 4 | aripuana
# Processing Record 36 of Set 4 | saint-pierre
# Processing Record 37 of Set 4 | yerbogachen
# Processing Record 38 of Set 4 | beringovskiy
# Processing Record 39 of Set 4 | kasulu
# Processing Record 40 of Set 4 | nantucket
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | cape canaveral
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | iquique
# Processing Record 46 of Set 4 | foumban
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | nha trang
# Processing Record 49 of Set 4 | swan hill
# Processing Record 0 of Set 5 | davila
# Processing Record 1 of Set 5 | honiara
# Processing Record 2 of Set 5 | nabire
# Processing Record 3 of Set 5 | camacha
# Processing Record 4 of Set 5 | skelleftea
# Processing Record 5 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | alta floresta
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | unye
# City not found. Skipping...
# Processing Record 9 of Set 5 | contamana
# Processing Record 10 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 5 | srednekolymsk
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 5 | tabory
# Processing Record 15 of Set 5 | mashhad
# Processing Record 16 of Set 5 | thinadhoo
# Processing Record 17 of Set 5 | maceio
# Processing Record 18 of Set 5 | constantine
# Processing Record 19 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 5 | mayumba
# Processing Record 21 of Set 5 | nizhniy kuranakh
# Processing Record 22 of Set 5 | plouzane
# Processing Record 23 of Set 5 | storslett
# Processing Record 24 of Set 5 | la union
# Processing Record 25 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 26 of Set 5 | ixtapa
# Processing Record 27 of Set 5 | sovetskiy
# Processing Record 28 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | townsville
# Processing Record 30 of Set 5 | damaturu
# Processing Record 31 of Set 5 | kholtoson
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | kloulklubed
# Processing Record 34 of Set 5 | poum
# Processing Record 35 of Set 5 | masalli
# Processing Record 36 of Set 5 | alugan
# Processing Record 37 of Set 5 | varhaug
# Processing Record 38 of Set 5 | luoyang
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | anaco
# Processing Record 41 of Set 5 | bradford
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | chavantes
# Processing Record 44 of Set 5 | port lincoln
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | shahr-e babak
# Processing Record 47 of Set 5 | port macquarie
# Processing Record 48 of Set 5 | dicabisagan
# Processing Record 49 of Set 5 | narsaq
# Processing Record 0 of Set 6 | bolgar
# Processing Record 1 of Set 6 | keflavik
# Processing Record 2 of Set 6 | altay
# Processing Record 3 of Set 6 | fangshan
# Processing Record 4 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | udachnyy
# Processing Record 6 of Set 6 | vilyuysk
# Processing Record 7 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 6 | edgewater
# Processing Record 9 of Set 6 | birin
# Processing Record 10 of Set 6 | sawakin
# Processing Record 11 of Set 6 | puerto madryn
# Processing Record 12 of Set 6 | labuhan
# Processing Record 13 of Set 6 | betioky
# Processing Record 14 of Set 6 | berdigestyakh
# Processing Record 15 of Set 6 | changde
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 6 | imbituba
# Processing Record 19 of Set 6 | tucuman
# Processing Record 20 of Set 6 | oktyabrskiy
# Processing Record 21 of Set 6 | sinnamary
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | abu kamal
# Processing Record 24 of Set 6 | atasu
# Processing Record 25 of Set 6 | iqaluit
# Processing Record 26 of Set 6 | xining
# Processing Record 27 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 6 | palana
# Processing Record 29 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 6 | merauke
# Processing Record 31 of Set 6 | tura
# Processing Record 32 of Set 6 | la paz
# Processing Record 33 of Set 6 | zhigansk
# Processing Record 34 of Set 6 | batemans bay
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | hay river
# Processing Record 37 of Set 6 | scottsbluff
# Processing Record 38 of Set 6 | port-gentil
# Processing Record 39 of Set 6 | brae
# Processing Record 40 of Set 6 | aguas vermelhas
# Processing Record 41 of Set 6 | hvide sande
# Processing Record 42 of Set 6 | bend
# Processing Record 43 of Set 6 | oksfjord
# Processing Record 44 of Set 6 | guarapari
# Processing Record 45 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 6 | moranbah
# Processing Record 47 of Set 6 | tarko-sale
# Processing Record 48 of Set 6 | mao
# Processing Record 49 of Set 6 | villa de cura
# Processing Record 0 of Set 7 | kedrovyy
# Processing Record 1 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 2 of Set 7 | isangel
# Processing Record 3 of Set 7 | te anau
# Processing Record 4 of Set 7 | ossora
# Processing Record 5 of Set 7 | neiafu
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | kearney
# Processing Record 8 of Set 7 | bud
# Processing Record 9 of Set 7 | galle
# Processing Record 10 of Set 7 | victoria
# Processing Record 11 of Set 7 | srandakan
# Processing Record 12 of Set 7 | ketchikan
# Processing Record 13 of Set 7 | astana
# Processing Record 14 of Set 7 | hithadhoo
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | zile
# Processing Record 17 of Set 7 | caceres
# Processing Record 18 of Set 7 | stornoway
# Processing Record 19 of Set 7 | isla vista
# Processing Record 20 of Set 7 | lagoa
# Processing Record 21 of Set 7 | ippy
# Processing Record 22 of Set 7 | naryan-mar
# Processing Record 23 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | kingaroy
# Processing Record 27 of Set 7 | westport
# Processing Record 28 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | marsh harbour
# Processing Record 30 of Set 7 | alice springs
# Processing Record 31 of Set 7 | nemuro
# Processing Record 32 of Set 7 | lasa
# Processing Record 33 of Set 7 | vlagtwedde
# Processing Record 34 of Set 7 | lethem
# Processing Record 35 of Set 7 | tula
# Processing Record 36 of Set 7 | malibu
# Processing Record 37 of Set 7 | genhe
# Processing Record 38 of Set 7 | peniche
# Processing Record 39 of Set 7 | caravelas
# Processing Record 40 of Set 7 | malanje
# Processing Record 41 of Set 7 | deputatskiy
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | una
# Processing Record 44 of Set 7 | fort-shevchenko
# Processing Record 45 of Set 7 | beyneu
# Processing Record 46 of Set 7 | mackay
# Processing Record 47 of Set 7 | cleburne
# Processing Record 48 of Set 7 | waverley
# Processing Record 49 of Set 7 | tete
# Processing Record 0 of Set 8 | luderitz
# Processing Record 1 of Set 8 | gouyave
# Processing Record 2 of Set 8 | kot addu
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | guanica
# Processing Record 6 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 8 | george
# Processing Record 8 of Set 8 | shikohabad
# Processing Record 9 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record
# Processing Record 39 of Set 9 | sao jose da coroa grande
# Processing Record 40 of Set 9 | sokolo
# Processing Record 41 of Set 9 | xinzhou
# Processing Record 42 of Set 9 | kaspi
# Processing Record 43 of Set 9 | tocopilla
# Processing Record 44 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | piriyapatna
# Processing Record 47 of Set 9 | santa rosa
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | gao
# Processing Record 0 of Set 10 | magetan
# City not found. Skipping...
# Processing Record 1 of Set 10 | puerto suarez
# Processing Record 2 of Set 10 | conceicao do araguaia
# Processing Record 3 of Set 10 | korem
# Processing Record 4 of Set 10 | barillas
# Processing Record 5 of Set 10 | thohoyandou
# Processing Record 6 of Set 10 | tigre
# Processing Record 7 of Set 10 | karoi
# Processing Record 8 of Set 10 | pitimbu
# Processing Record 9 of Set 10 | guiratinga
# Processing Record 10 of Set 10 | balkhash
# Processing Record 11 of Set 10 | mount gambier
# Processing Record 12 of Set 10 | baykit
# Processing Record 13 of Set 10 | kajaani
# Processing Record 14 of Set 10 | bonavista
# Processing Record 15 of Set 10 | gazanjyk
# Processing Record 16 of Set 10 | santa vitoria do palmar
# Processing Record 17 of Set 10 | burgos
# Processing Record 18 of Set 10 | zheleznodorozhnyy
# Processing Record 19 of Set 10 | betare oya
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | sarankhola
# Processing Record 25 of Set 10 | bubaque
# Processing Record 26 of Set 10 | tevaitoa
# Processing Record 27 of Set 10 | elk grove
# Processing Record 28 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 10 | padre paraiso
# Processing Record 30 of Set 10 | ames
# Processing Record 31 of Set 10 | marzuq
# Processing Record 32 of Set 10 | iralaya
# Processing Record 33 of Set 10 | harper
# Processing Record 34 of Set 10 | angoche
# Processing Record 35 of Set 10 | golyshmanovo
# Processing Record 36 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 10 | nelson bay
# Processing Record 39 of Set 10 | petropavl
# Processing Record 40 of Set 10 | inuvik
# Processing Record 41 of Set 10 | kendari
# Processing Record 42 of Set 10 | dickinson
# Processing Record 43 of Set 10 | niquelandia
# Processing Record 44 of Set 10 | tucupita
# Processing Record 45 of Set 10 | zeya
# Processing Record 46 of Set 10 | leh
# Processing Record 47 of Set 10 | cairns
# Processing Record 48 of Set 10 | valparaiso
# Processing Record 49 of Set 10 | feicheng
# Processing Record 0 of Set 11 | nouadhibou
# Processing Record 1 of Set 11 | wewak
# Processing Record 2 of Set 11 | vesyegonsk
# Processing Record 3 of Set 11 | soyo
# Processing Record 4 of Set 11 | ocampo
# Processing Record 5 of Set 11 | atherton
# Processing Record 6 of Set 11 | bilibino
# Processing Record 7 of Set 11 | chicama
# Processing Record 8 of Set 11 | ayolas
# Processing Record 9 of Set 11 | el centro
# Processing Record 10 of Set 11 | turayf
# Processing Record 11 of Set 11 | harpalpur
# Processing Record 12 of Set 11 | geraldton
# Processing Record 13 of Set 11 | mitu
# Processing Record 14 of Set 11 | ornskoldsvik
# Processing Record 15 of Set 11 | springbok
# Processing Record 16 of Set 11 | santa cecilia
# Processing Record 17 of Set 11 | bantogon
# Processing Record 18 of Set 11 | sao filipe
# Processing Record 19 of Set 11 | gympie
# Processing Record 20 of Set 11 | roebourne
# Processing Record 21 of Set 11 | canutama
# Processing Record 22 of Set 11 | quepos
# Processing Record 23 of Set 11 | zhangye
# Processing Record 24 of Set 11 | fort abbas
# Processing Record 25 of Set 11 | vitre
# Processing Record 26 of Set 11 | ishigaki
# Processing Record 27 of Set 11 | oudtshoorn
# Processing Record 28 of Set 11 | wadi maliz
# Processing Record 29 of Set 11 | vila velha
# Processing Record 30 of Set 11 | rocha
# Processing Record 31 of Set 11 | storsteinnes
# Processing Record 32 of Set 11 | lewiston
# Processing Record 33 of Set 11 | maarianhamina
# Processing Record 34 of Set 11 | opunake
# Processing Record 35 of Set 11 | kansk
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | sabla
# Processing Record 38 of Set 11 | san cristobal
# Processing Record 39 of Set 11 | kilindoni
# Processing Record 40 of Set 11 | mangawan
# Processing Record 41 of Set 11 | chernyshevskiy
# Processing Record 42 of Set 11 | mnogovershinnyy
# Processing Record 43 of Set 11 | metro
# Processing Record 44 of Set 11 | kupang
# Processing Record 45 of Set 11 | prattville
# Processing Record 46 of Set 11 | dunda
# Processing Record 47 of Set 11 | matagami
# Processing Record 48 of Set 11 | scarborough
# Processing Record 49 of Set 11 | eskil
# Processing Record 0 of Set 12 | flinders
# Processing Record 1 of Set 12 | hatillo
# Processing Record 2 of Set 12 | ambatondrazaka
# Processing Record 3 of Set 12 | charters towers
# Processing Record 4 of Set 12 | komatipoort
# Processing Record 5 of Set 12 | severnyy
# Processing Record 6 of Set 12 | trairi
# Processing Record 7 of Set 12 | leshukonskoye
# Processing Record 8 of Set 12 | brasileia
# Processing Record 9 of Set 12 | airai
# Processing Record 10 of Set 12 | tokoroa
# Processing Record 11 of Set 12 | vaitape
# Processing Record 12 of Set 12 | troitsko-pechorsk
# Processing Record 13 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 12 | rawlins
# Processing Record 15 of Set 12 | waipawa
# Processing Record 16 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | lingao
# Processing Record 19 of Set 12 | port said
# Processing Record 20 of Set 12 | siparia
# Processing Record 21 of Set 12 | slantsy
# Processing Record 22 of Set 12 | elizabeth city
# Processing Record 23 of Set 12 | antalaha
# Processing Record 24 of Set 12 | ous
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 12 | stephenville
# Processing Record 28 of Set 12 | jumla
# Processing Record 29 of Set 12 | kavaratti
# Processing Record 30 of Set 12 | domoni
# Processing Record 31 of Set 12 | sande
# Processing Record 32 of Set 12 | lixourion
# Processing Record 33 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | del rio
# Processing Record 35 of Set 12 | saint anthony
# Processing Record 36 of Set 12 | anchorage
# Processing Record 37 of Set 12 | kilinochchi
# Processing Record 38 of Set 12 | linxia
# Processing Record 39 of Set 12 | kem
# Processing Record 40 of Set 12 | masallatah
# Processing Record 41 of Set 12 | bambey
# Processing Record 42 of Set 12 | katsuura
# Processing Record 43 of Set 12 | bandarbeyla
# Processing Record 44 of Set 12 | komsomolskiy
# Processing Record 45 of Set 12 | kalaiya
# Processing Record 46 of Set 12 | sakakah
# Processing Record 47 of Set 12 | talaya
# Processing Record 48 of Set 12 | lima
# Processing Record 49 of Set 12 | waingapu
# Processing Record 0 of Set 13 | lazaro cardenas
# Processing Record 1 of Set 13 | ayagoz
# Processing Record 2 of Set 13 | yarada
# Processing Record 3 of Set 13 | pokhara
# Processing Record 4 of Set 13 | innisfail
# Processing Record 5 of Set 13 | praia
# Processing Record 6 of Set 13 | rosetown
# Processing Record 7 of Set 13 | bastia
# Processing Record 8 of Set 13 | lurate caccivio
# Processing Record 9 of Set 13 | tarata
# Processing Record 10 of Set 13 | bintulu
# Processing Record 11 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 13 | langres
# Processing Record 13 of Set 13 | berlevag
# Processing Record 14 of Set 13 | nazas
# Processing Record 15 of Set 13 | griffith
# Processing Record 16 of Set 13 | xinzhi
# Processing Record 17 of Set 13 | khandyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 565

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    hobart -42.8794  147.3294     53.60        71          51        9.22
# 1    pinega  64.7001   43.3936     24.40        95           9        5.46
# 2    kodiak  57.7900 -152.4072     30.20        43           1       11.50
# 3    nobres -14.7203  -56.3275     90.34        46          27        3.36
# 4  cidreira -30.1811  -50.2056     77.65        76          98        6.46
#
#   Country        Date
# 0      AU  1616867612
# 1      RU  1616868124
# 2      US  1616867808
# 3      BR  1616868125
# 4      BR  1616867837

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    19.514770   19.063856   58.007080   69.736283   51.994690    8.457133
# std     33.666804   90.215959   27.116715   22.932127   38.561478    6.692601
# min    -54.800000 -175.200000  -25.600000    1.000000    0.000000    0.130000
# 25%     -9.665800  -60.633300   42.800000   57.000000   13.000000    3.940000
# 50%     22.788600   21.024700   66.000000   74.000000   55.000000    6.910000
# 75%     49.416900  100.451700   78.800000   88.000000   90.000000   11.320000
# max     78.218600  179.316700  109.400000  100.000000  100.000000   50.640000
#
#                Date
# count  5.650000e+02
# mean   1.616868e+09
# std    1.680028e+02
# min    1.616867e+09
# 25%    1.616868e+09
# 50%    1.616868e+09
# 75%    1.616868e+09
# max    1.616868e+09

# %%
#  Get the indices of cities that have humidity over 100%.
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    hobart -42.8794  147.3294     53.60        71          51        9.22
# 1    pinega  64.7001   43.3936     24.40        95           9        5.46
# 2    kodiak  57.7900 -152.4072     30.20        43           1       11.50
# 3    nobres -14.7203  -56.3275     90.34        46          27        3.36
# 4  cidreira -30.1811  -50.2056     77.65        76          98        6.46
#
#   Country        Date
# 0      AU  1616867612
# 1      RU  1616868124
# 2      US  1616867808
# 3      BR  1616868125
# 4      BR  1616867837

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-f63029d93d4f> in <module>
#       7
#       8 # Export the City_Data into a csv
# ----> 9 clean_city_data.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5ef3229c5b43> in <module>
#      12
#      13 # Save the figure
# ---> 14 plt.savefig("output_data/Fig1.png")
#      15
#      16 # Show plot
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1603         pil_kwargs.setdefault("format", format)
#    1604         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1605         image.save(fname, **pil_kwargs)
#    1606
#    1607
#
# ~\anaconda3\envs\PythonData\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2146                 fp = builtins.open(filename, "r+b")
#    2147             else:
# -> 2148                 fp = builtins.open(filename, "w+b")
#    2149
#    2150         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/Fig1.png'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.4385222622143718

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 90))
# Out:
# The r-value is: 0.6199397603726745

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature. R values ~ 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-value is: 0.0016116777278289516

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))
# Out:
# The r-value is: 0.0038626940821578

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-value is: 2.5990039670556435e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-value is: 0.009647394310294634

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-value is: 0.005590882726654447

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# The r-value is: 0.015078836518603362

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
