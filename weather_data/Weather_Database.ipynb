# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
from citipy import citipy

import sys

sys.path.insert(1,'C:/Users/chris/CU-Repositories/')

#Import API key
from config import g_key
#Import the API key.
# from config import weather_api_key

weather_api_key = "6cb990c73e89fb81dab285393417f0a8"

# g_key = "AIzaSyD68m_1emaZzaC-zXoayaACZdwuXzbH548"

# Configure gmaps
gmaps.configure(api_key=g_key)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)

# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6cb990c73e89fb81dab285393417f0a8

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# create an empty list to hold weather data
city_data = []
# print the beginning of the logging
print("Beginning Data Retrieval")
print("-------------------------")
# create counters
record_count = 1
set_count = 1
# loop through all the cities in our list
for i, city in enumerate(cities):
    # group the cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    # create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    # log the url, record and set numbers and the city.
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    # add 1 to the record count
    record_count += 1
# run an api request for each of the cities
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # convert the date to iso standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # append the city info into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Max Temp": city_max_temp,
                         "Current Description": city_description})
# if an error is experienced, skip the city
    except:
        print("City not found. Skipping ...")
        pass
    # indicate that Data loading is complete
print("----------------------")
print("Data Retrieval Complete")
print("----------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of set 1 | gat
# Processing Record 2 of set 1 | satitoa
# City not found. Skipping ...
# Processing Record 3 of set 1 | barrow
# Processing Record 4 of set 1 | jaguarari
# Processing Record 5 of set 1 | hilo
# Processing Record 6 of set 1 | ushuaia
# Processing Record 7 of set 1 | flin flon
# Processing Record 8 of set 1 | thompson
# Processing Record 9 of set 1 | arraial do cabo
# Processing Record 10 of set 1 | punta arenas
# Processing Record 11 of set 1 | blagoyevo
# Processing Record 12 of set 1 | chuy
# Processing Record 13 of set 1 | bredasdorp
# Processing Record 14 of set 1 | mataura
# Processing Record 15 of set 1 | salcininkai
# Processing Record 16 of set 1 | torbay
# Processing Record 17 of set 1 | dustlik
# Processing Record 18 of set 1 | matiguas
# Processing Record 19 of set 1 | rikitea
# Processing Record 20 of set 1 | rosario
# Processing Record 21 of set 1 | margate
# Processing Record 22 of set 1 | kiama
# Processing Record 23 of set 1 | tasiilaq
# Processing Record 24 of set 1 | samarai
# Processing Record 25 of set 1 | kattivakkam
# Processing Record 26 of set 1 | jalu
# Processing Record 27 of set 1 | puerto ayora
# Processing Record 28 of set 1 | albany
# Processing Record 29 of set 1 | asau
# Processing Record 30 of set 1 | agadez
# Processing Record 31 of set 1 | leningradskiy
# Processing Record 32 of set 1 | arman
# Processing Record 33 of set 1 | necochea
# Processing Record 34 of set 1 | praia da vitoria
# Processing Record 35 of set 1 | mahebourg
# Processing Record 36 of set 1 | ijaki
# City not found. Skipping ...
# Processing Record 37 of set 1 | lompoc
# Processing Record 38 of set 1 | kuusamo
# Processing Record 39 of set 1 | garoua boulai
# Processing Record 40 of set 1 | nogales
# Processing Record 41 of set 1 | tres arroyos
# Processing Record 42 of set 1 | hambantota
# Processing Record 43 of set 1 | loknya
# Processing Record 44 of set 1 | alotau
# City not found. Skipping ...
# Processing Record 45 of set 1 | kulu
# Processing Record 46 of set 1 | qaanaaq
# Processing Record 47 of set 1 | pacific grove
# Processing Record 48 of set 1 | sao filipe
# Processing Record 49 of set 1 | ribeira grande
# Processing Record 50 of set 1 | port elizabeth
# Processing Record 52 of set 2 | husavik
# Processing Record 53 of set 2 | nizhneyansk
# City not found. Skipping ...
# Processing Record 54 of set 2 | gilgil
# City not found. Skipping ...
# Processing Record 55 of set 2 | luderitz
# Processing Record 56 of set 2 | port-gentil
# Processing Record 57 of set 2 | airai
# Processing Record 58 of set 2 | taolanaro
# City not found. Skipping ...
# Processing Record 59 of set 2 | cape town
# Processing Record 60 of set 2 | new norfolk
# Processing Record 61 of set 2 | saint-pierre
# Processing Record 62 of set 2 | maumere
# Processing Record 63 of set 2 | busselton
# Processing Record 64 of set 2 | kulhudhuffushi
# Processing Record 65 of set 2 | hasaki
# Processing Record 66 of set 2 | ternuvate
# Processing Record 67 of set 2 | sisimiut
# Processing Record 68 of set 2 | avarua
# Processing Record 69 of set 2 | mys shmidta
# City not found. Skipping ...
# Processing Record 70 of set 2 | cobija
# Processing Record 71 of set 2 | antofagasta
# Processing Record 72 of set 2 | dunedin
# Processing Record 73 of set 2 | georgetown
# Processing Record 74 of set 2 | vanimo
# Processing Record 75 of set 2 | kumluca
# Processing Record 76 of set 2 | podor
# Processing Record 77 of set 2 | vila velha
# Processing Record 78 of set 2 | ponta do sol
# Processing Record 79 of set 2 | klaksvik
# Processing Record 80 of set 2 | cherskiy
# Processing Record 81 of set 2 | tambun
# Processing Record 82 of set 2 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 83 of set 2 | cabo san lucas
# Processing Record 84 of set 2 | artyk
# City not found. Skipping ...
# Processing Record 85 of set 2 | kaitangata
# Processing Record 86 of set 2 | kapaa
# Processing Record 87 of set 2 | provideniya
# Processing Record 88 of set 2 | tuatapere
# Processing Record 89 of set 2 | mirnyy
# Processing Record 90 of set 2 | christchurch
# Processing Record 91 of set 2 | upernavik
# Processing Record 92 of set 2 | kodiak
# Processing Record 93 of set 2 | attawapiskat
# City not found. Skipping ...
# Processing Record 94 of set 2 | pyapon
# Processing Record 95 of set 2 | tucurui
# Processing Record 96 of set 2 | pevek
# Processing Record 97 of set 2 | saint george
# Processing Record 98 of set 2 | hithadhoo
# Processing Record 99 of set 2 | bodaybo
# Processing Record 100 of set 2 | palmer
# Processing Record 101 of set 2 | codrington
# Processing Record 103 of set 3 | isabela
# Processing Record 104 of set 3 | atuona
# Processing Record 105 of set 3 | wausau
# Processing Record 106 of set 3 | lahat
# Processing Record 107 of set 3 | tiksi
# Processing Record 108 of set 3 | barbar
# City not found. Skipping ...
# Processing Record 109 of set 3 | hobart
# Processing Record 110 of set 3 | thinadhoo
# Processing Record 111 of set 3 | charleston
# Processing Record 112 of set 3 | san quintin
# Processing Record 113 of set 3 | sambava
# Processing Record 114 of set 3 | kudahuvadhoo
# Processing Record 115 of set 3 | mecca
# Processing Record 116 of set 3 | talnakh
# Processing Record 117 of set 3 | corod
# Processing Record 118 of set 3 | samusu
# City not found. Skipping ...
# Processing Record 119 of set 3 | namatanai
# Processing Record 120 of set 3 | dubbo
# Processing Record 121 of set 3 | placido de castro
# Processing Record 122 of set 3 | victoria
# Processing Record 123 of set 3 | bluff
# Processing Record 124 of set 3 | jamestown
# Processing Record 125 of set 3 | ketchikan
# Processing Record 126 of set 3 | samut sakhon
# Processing Record 127 of set 3 | santiago del estero
# Processing Record 128 of set 3 | sitka
# Processing Record 129 of set 3 | bethel
# Processing Record 130 of set 3 | bengkulu
# Processing Record 131 of set 3 | vaini
# Processing Record 132 of set 3 | saleaula
# City not found. Skipping ...
# Processing Record 133 of set 3 | okhotsk
# Processing Record 134 of set 3 | los llanos de aridane
# Processing Record 135 of set 3 | lazaro cardenas
# Processing Record 136 of set 3 | norman wells
# Processing Record 137 of set 3 | clyde river
# Processing Record 138 of set 3 | novoselitskoye
# Processing Record 139 of set 3 | naze
# Processing Record 140 of set 3 | dikson
# Processing Record 141 of set 3 | xining
# Processing Record 142 of set 3 | lorengau
# Processing Record 143 of set 3 | ancud
# Processing Record 144 of set 3 | maunabo
# Processing Record 145 of set 3 | doboj
# Processing Record 146 of set 3 | saint-philippe
# Processing Record 147 of set 3 | broken hill
# Processing Record 148 of set 3 | bastia
# Processing Record 149 of set 3 | vaitupu
# City not found. Skipping ...
# Processing Record 150 of set 3 | kisanga
# Processing Record 151 of set 3 | port alfred
# Processing Record 152 of set 3 | nikolskoye
# Processing Record 154 of set 4 | lebu
# Processing Record 155 of set 4 | saint-joseph
# Processing Record 156 of set 4 | juterbog
# Processing Record 157 of set 4 | cidreira
# Processing Record 158 of set 4 | lar gerd
# City not found. Skipping ...
# Processing Record 159 of set 4 | hami
# Processing Record 160 of set 4 | tuktoyaktuk
# Processing Record 161 of set 4 | jiuquan
# Processing Record 162 of set 4 | kilimatinde
# Processing Record 163 of set 4 | sinnamary
# Processing Record 164 of set 4 | astana
# Processing Record 165 of set 4 | kahului
# Processing Record 166 of set 4 | jasper
# Processing Record 167 of set 4 | barentsburg
# City not found. Skipping ...
# Processing Record 168 of set 4 | kefamenanu
# Processing Record 169 of set 4 | hermanus
# Processing Record 170 of set 4 | mezen
# Processing Record 171 of set 4 | butaritari
# Processing Record 172 of set 4 | atemar
# Processing Record 173 of set 4 | esso
# Processing Record 174 of set 4 | vardo
# Processing Record 175 of set 4 | kruisfontein
# Processing Record 176 of set 4 | burnie
# Processing Record 177 of set 4 | turukhansk
# Processing Record 178 of set 4 | shingu
# Processing Record 179 of set 4 | khatanga
# Processing Record 180 of set 4 | kavieng
# Processing Record 181 of set 4 | palabuhanratu
# City not found. Skipping ...
# Processing Record 182 of set 4 | ilulissat
# Processing Record 183 of set 4 | pitimbu
# Processing Record 184 of set 4 | tura
# Processing Record 185 of set 4 | pisco
# Processing Record 186 of set 4 | dhidhdhoo
# Processing Record 187 of set 4 | broome
# Processing Record 188 of set 4 | abbotsford
# Processing Record 189 of set 4 | coihaique
# Processing Record 190 of set 4 | severo-kurilsk
# Processing Record 191 of set 4 | touros
# Processing Record 192 of set 4 | tucumcari
# Processing Record 193 of set 4 | mar del plata
# Processing Record 194 of set 4 | kihei
# Processing Record 195 of set 4 | yellowknife
# Processing Record 196 of set 4 | maceio
# Processing Record 197 of set 4 | nyrob
# Processing Record 198 of set 4 | bollnas
# Processing Record 199 of set 4 | muroto
# Processing Record 200 of set 4 | basco
# Processing Record 201 of set 4 | srednekolymsk
# Processing Record 202 of set 4 | balimo
# City not found. Skipping ...
# Processing Record 203 of set 4 | show low
# Processing Record 205 of set 5 | grand river south east
# City not found. Skipping ...
# Processing Record 206 of set 5 | tuni
# Processing Record 207 of set 5 | mezhdurechensk
# Processing Record 208 of set 5 | san cristobal
# Processing Record 209 of set 5 | price
# Processing Record 210 of set 5 | portland
# Processing Record 211 of set 5 | gazalkent
# Processing Record 212 of set 5 | ahipara
# Processing Record 213 of set 5 | xai-xai
# Processing Record 214 of set 5 | puerto escondido
# Processing Record 215 of set 5 | saldanha
# Processing Record 216 of set 5 | tandil
# Processing Record 217 of set 5 | ostrovnoy
# Processing Record 218 of set 5 | east london
# Processing Record 219 of set 5 | jimo
# Processing Record 220 of set 5 | geraldton
# Processing Record 221 of set 5 | golden
# Processing Record 222 of set 5 | cochrane
# Processing Record 223 of set 5 | mayo
# Processing Record 224 of set 5 | beringovskiy
# Processing Record 225 of set 5 | boguchany
# Processing Record 226 of set 5 | sierra vista
# Processing Record 227 of set 5 | richards bay
# Processing Record 228 of set 5 | sorong
# Processing Record 229 of set 5 | pontian kecil
# Processing Record 230 of set 5 | taltal
# Processing Record 231 of set 5 | kyabe
# Processing Record 232 of set 5 | atasu
# Processing Record 233 of set 5 | tiarei
# Processing Record 234 of set 5 | yumen
# Processing Record 235 of set 5 | kulevcha
# Processing Record 236 of set 5 | wau
# Processing Record 237 of set 5 | fairbanks
# Processing Record 238 of set 5 | marawi
# Processing Record 239 of set 5 | castro
# Processing Record 240 of set 5 | padang
# Processing Record 241 of set 5 | poum
# Processing Record 242 of set 5 | cabedelo
# Processing Record 243 of set 5 | okitipupa
# Processing Record 244 of set 5 | saskylakh
# Processing Record 245 of set 5 | caravelas
# Processing Record 246 of set 5 | iqaluit
# Processing Record 247 of set 5 | antsohihy
# Processing Record 248 of set 5 | karkaralinsk
# City not found. Skipping ...
# Processing Record 249 of set 5 | puerto maldonado
# Processing Record 250 of set 5 | bida
# Processing Record 251 of set 5 | bubaque
# Processing Record 252 of set 5 | aflu
# City not found. Skipping ...
# Processing Record 253 of set 5 | port augusta
# Processing Record 254 of set 5 | ayagoz
# Processing Record 256 of set 6 | parsabad
# Processing Record 257 of set 6 | chokwe
# Processing Record 258 of set 6 | saint-augustin
# Processing Record 259 of set 6 | vila franca do campo
# Processing Record 260 of set 6 | kerema
# Processing Record 261 of set 6 | dingle
# Processing Record 262 of set 6 | yatou
# Processing Record 263 of set 6 | big bend
# Processing Record 264 of set 6 | karaul
# City not found. Skipping ...
# Processing Record 265 of set 6 | suhbaatar
# Processing Record 266 of set 6 | high level
# Processing Record 267 of set 6 | boa vista
# Processing Record 268 of set 6 | boljarovo
# City not found. Skipping ...
# Processing Record 269 of set 6 | eskasem
# City not found. Skipping ...
# Processing Record 270 of set 6 | rossland
# Processing Record 271 of set 6 | karakose
# City not found. Skipping ...
# Processing Record 272 of set 6 | iracoubo
# Processing Record 273 of set 6 | lucapa
# Processing Record 274 of set 6 | uglegorsk
# Processing Record 275 of set 6 | belaya gora
# Processing Record 276 of set 6 | darhan
# Processing Record 277 of set 6 | nanortalik
# Processing Record 278 of set 6 | college
# Processing Record 279 of set 6 | zyryanka
# Processing Record 280 of set 6 | loanda
# Processing Record 281 of set 6 | kardla
# Processing Record 282 of set 6 | victor harbor
# Processing Record 283 of set 6 | talaya
# Processing Record 284 of set 6 | katsuura
# Processing Record 285 of set 6 | sohag
# Processing Record 286 of set 6 | felidhoo
# City not found. Skipping ...
# Processing Record 287 of set 6 | salalah
# Processing Record 288 of set 6 | belushya guba
# City not found. Skipping ...
# Processing Record 289 of set 6 | ustye
# Processing Record 290 of set 6 | hanstholm
# Processing Record 291 of set 6 | eydhafushi
# Processing Record 292 of set 6 | tadine
# Processing Record 293 of set 6 | kyra
# Processing Record 294 of set 6 | lianzhou
# Processing Record 295 of set 6 | sines
# Processing Record 296 of set 6 | alofi
# Processing Record 297 of set 6 | booue
# Processing Record 298 of set 6 | songkhla
# Processing Record 299 of set 6 | mount gambier
# Processing Record 300 of set 6 | sahrak
# City not found. Skipping ...
# Processing Record 301 of set 6 | sobolevo
# Processing Record 302 of set 6 | komatipoort
# Processing Record 303 of set 6 | lata
# Processing Record 304 of set 6 | nelson bay
# Processing Record 305 of set 6 | kurchum
# Processing Record 307 of set 7 | ajnala
# Processing Record 308 of set 7 | tasbuget
# City not found. Skipping ...
# Processing Record 309 of set 7 | tessalit
# Processing Record 310 of set 7 | upington
# Processing Record 311 of set 7 | namibe
# Processing Record 312 of set 7 | marcona
# City not found. Skipping ...
# Processing Record 313 of set 7 | matsanga
# City not found. Skipping ...
# Processing Record 314 of set 7 | port hardy
# Processing Record 315 of set 7 | wasilla
# Processing Record 316 of set 7 | bahia blanca
# Processing Record 317 of set 7 | kiunga
# Processing Record 318 of set 7 | manokwari
# Processing Record 319 of set 7 | isla vista
# Processing Record 320 of set 7 | mamboma
# Processing Record 321 of set 7 | bemidji
# Processing Record 322 of set 7 | gostinu
# Processing Record 323 of set 7 | lavrentiya
# Processing Record 324 of set 7 | anchorage
# Processing Record 325 of set 7 | baykit
# Processing Record 326 of set 7 | shimoda
# Processing Record 327 of set 7 | buala
# Processing Record 328 of set 7 | plettenberg bay
# Processing Record 329 of set 7 | bocas del toro
# Processing Record 330 of set 7 | ziro
# Processing Record 331 of set 7 | gatesville
# Processing Record 332 of set 7 | norrkoping
# Processing Record 333 of set 7 | biak
# Processing Record 334 of set 7 | fairview
# Processing Record 335 of set 7 | amderma
# City not found. Skipping ...
# Processing Record 336 of set 7 | carnarvon
# Processing Record 337 of set 7 | bodden town
# Processing Record 338 of set 7 | ixtapa
# Processing Record 339 of set 7 | nuuk
# Processing Record 340 of set 7 | greencastle
# Processing Record 341 of set 7 | vylgort
# City not found. Skipping ...
# Processing Record 342 of set 7 | pontiac
# Processing Record 343 of set 7 | le vauclin
# Processing Record 344 of set 7 | rocha
# Processing Record 345 of set 7 | tilichiki
# Processing Record 346 of set 7 | eureka
# Processing Record 347 of set 7 | haibowan
# City not found. Skipping ...
# Processing Record 348 of set 7 | mossendjo
# Processing Record 349 of set 7 | vezirkopru
# Processing Record 350 of set 7 | nemuro
# Processing Record 351 of set 7 | matara
# Processing Record 352 of set 7 | palmares do sul
# Processing Record 353 of set 7 | batagay-alyta
# Processing Record 354 of set 7 | hammerfest
# Processing Record 355 of set 7 | sao felix do xingu
# Processing Record 356 of set 7 | saint-francois
# Processing Record 358 of set 8 | saint anthony
# Processing Record 359 of set 8 | orito
# Processing Record 360 of set 8 | gorin
# Processing Record 361 of set 8 | vila
# Processing Record 362 of set 8 | port-cartier
# Processing Record 363 of set 8 | opportunity
# Processing Record 364 of set 8 | ostersund
# Processing Record 365 of set 8 | sao miguel do araguaia
# Processing Record 366 of set 8 | chokurdakh
# Processing Record 367 of set 8 | rancho palos verdes
# Processing Record 368 of set 8 | miguelopolis
# Processing Record 369 of set 8 | kenora
# Processing Record 370 of set 8 | taraza
# Processing Record 371 of set 8 | glendive
# Processing Record 372 of set 8 | guerrero negro
# Processing Record 373 of set 8 | necocli
# Processing Record 374 of set 8 | patiya
# Processing Record 375 of set 8 | vostok
# Processing Record 376 of set 8 | maniwaki
# Processing Record 377 of set 8 | gorgan
# Processing Record 378 of set 8 | wattegama
# Processing Record 379 of set 8 | half moon bay
# Processing Record 380 of set 8 | kamen-na-obi
# Processing Record 381 of set 8 | san jeronimo
# Processing Record 382 of set 8 | ugoofaaru
# Processing Record 383 of set 8 | floriano
# Processing Record 384 of set 8 | gravdal
# Processing Record 385 of set 8 | ascension
# Processing Record 386 of set 8 | bolungarvik
# City not found. Skipping ...
# Processing Record 387 of set 8 | keuruu
# Processing Record 388 of set 8 | faanui
# Processing Record 389 of set 8 | chagda
# City not found. Skipping ...
# Processing Record 390 of set 8 | chicama
# Processing Record 391 of set 8 | qandala
# Processing Record 392 of set 8 | getashen
# Processing Record 393 of set 8 | hovd
# Processing Record 394 of set 8 | pangnirtung
# Processing Record 395 of set 8 | terre-de-bas
# Processing Record 396 of set 8 | hofn
# Processing Record 397 of set 8 | aragarcas
# Processing Record 398 of set 8 | kangaatsiaq
# Processing Record 399 of set 8 | aklavik
# Processing Record 400 of set 8 | atikokan
# Processing Record 401 of set 8 | abha
# Processing Record 402 of set 8 | tabiauea
# City not found. Skipping ...
# Processing Record 403 of set 8 | kelso
# Processing Record 404 of set 8 | aleksandrov gay
# Processing Record 405 of set 8 | longyearbyen
# Processing Record 406 of set 8 | waingapu
# Processing Record 407 of set 8 | quesnel
# Processing Record 409 of set 9 | phan thiet
# Processing Record 410 of set 9 | bichena
# Processing Record 411 of set 9 | north bend
# Processing Record 412 of set 9 | togur
# Processing Record 413 of set 9 | bambous virieux
# Processing Record 414 of set 9 | auki
# Processing Record 415 of set 9 | ituni
# City not found. Skipping ...
# Processing Record 416 of set 9 | chifeng
# Processing Record 417 of set 9 | rungata
# City not found. Skipping ...
# Processing Record 418 of set 9 | killybegs
# Processing Record 419 of set 9 | seddon
# Processing Record 420 of set 9 | santa vitoria do palmar
# Processing Record 421 of set 9 | kytlym
# City not found. Skipping ...
# Processing Record 422 of set 9 | naryan-mar
# Processing Record 423 of set 9 | whyalla
# Processing Record 424 of set 9 | zhigansk
# Processing Record 425 of set 9 | birin
# Processing Record 426 of set 9 | canico
# Processing Record 427 of set 9 | marrakesh
# Processing Record 428 of set 9 | mrirt
# City not found. Skipping ...
# Processing Record 429 of set 9 | dzhebariki-khaya
# Processing Record 430 of set 9 | san patricio
# Processing Record 431 of set 9 | roebourne
# Processing Record 432 of set 9 | louisbourg
# City not found. Skipping ...
# Processing Record 433 of set 9 | ust-nera
# Processing Record 434 of set 9 | hatillo
# Processing Record 435 of set 9 | kiruna
# Processing Record 436 of set 9 | charlottesville
# Processing Record 437 of set 9 | sergeyevka
# Processing Record 438 of set 9 | macheng
# Processing Record 439 of set 9 | bartica
# Processing Record 440 of set 9 | feijo
# Processing Record 441 of set 9 | kerouane
# Processing Record 442 of set 9 | lagoa
# Processing Record 443 of set 9 | la maddalena
# Processing Record 444 of set 9 | alipur duar
# City not found. Skipping ...
# Processing Record 445 of set 9 | constitucion
# Processing Record 446 of set 9 | mantua
# Processing Record 447 of set 9 | hualmay
# Processing Record 448 of set 9 | hendek
# Processing Record 449 of set 9 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 450 of set 9 | coahuayana
# Processing Record 451 of set 9 | otuzco
# Processing Record 452 of set 9 | kutum
# Processing Record 453 of set 9 | goderich
# Processing Record 454 of set 9 | san francisco
# Processing Record 455 of set 9 | kazalinsk
# City not found. Skipping ...
# Processing Record 456 of set 9 | utica
# Processing Record 457 of set 9 | zhanatas
# City not found. Skipping ...
# Processing Record 458 of set 9 | yaan
# Processing Record 460 of set 10 | dekoa
# City not found. Skipping ...
# Processing Record 461 of set 10 | nizhniy kuranakh
# Processing Record 462 of set 10 | bathsheba
# Processing Record 463 of set 10 | guilin
# Processing Record 464 of set 10 | lakes entrance
# Processing Record 465 of set 10 | egvekinot
# Processing Record 466 of set 10 | popondetta
# Processing Record 467 of set 10 | bonaventure
# Processing Record 468 of set 10 | stromness
# Processing Record 469 of set 10 | haines junction
# Processing Record 470 of set 10 | damghan
# Processing Record 471 of set 10 | urucara
# Processing Record 472 of set 10 | pemangkat
# Processing Record 473 of set 10 | tumannyy
# City not found. Skipping ...
# Processing Record 474 of set 10 | ambovombe
# Processing Record 475 of set 10 | port lincoln
# Processing Record 476 of set 10 | dao
# Processing Record 477 of set 10 | aloleng
# Processing Record 478 of set 10 | erenhot
# Processing Record 479 of set 10 | adet
# Processing Record 480 of set 10 | sarkand
# Processing Record 481 of set 10 | esperance
# Processing Record 482 of set 10 | krasnoselkup
# Processing Record 483 of set 10 | kongolo
# Processing Record 484 of set 10 | svetlyy
# Processing Record 485 of set 10 | adrar
# Processing Record 486 of set 10 | abu jubayhah
# City not found. Skipping ...
# Processing Record 487 of set 10 | pousat
# City not found. Skipping ...
# Processing Record 488 of set 10 | olinda
# Processing Record 489 of set 10 | korla
# Processing Record 490 of set 10 | serebryansk
# Processing Record 491 of set 10 | zachagansk
# City not found. Skipping ...
# Processing Record 492 of set 10 | buraydah
# Processing Record 493 of set 10 | tarko-sale
# Processing Record 494 of set 10 | willowmore
# Processing Record 495 of set 10 | veraval
# Processing Record 496 of set 10 | launceston
# Processing Record 497 of set 10 | russell
# Processing Record 498 of set 10 | ruatoria
# City not found. Skipping ...
# Processing Record 499 of set 10 | sayansk
# Processing Record 500 of set 10 | mitsamiouli
# Processing Record 501 of set 10 | yining
# Processing Record 502 of set 10 | ukiah
# Processing Record 503 of set 10 | mehamn
# Processing Record 504 of set 10 | kloulklubed
# Processing Record 505 of set 10 | mandalgovi
# Processing Record 506 of set 10 | gouyave
# Processing Record 507 of set 10 | nanded
# City not found. Skipping ...
# Processing Record 508 of set 10 | dakar
# Processing Record 509 of set 10 | hornepayne
# Processing Record 511 of set 11 | sorvag
# City not found. Skipping ...
# Processing Record 512 of set 11 | taguatinga
# Processing Record 513 of set 11 | suksun
# Processing Record 514 of set 11 | bahay
# Processing Record 515 of set 11 | khurianwala
# City not found. Skipping ...
# Processing Record 516 of set 11 | aasiaat
# Processing Record 517 of set 11 | tacuarembo
# Processing Record 518 of set 11 | foumbot
# Processing Record 519 of set 11 | bara
# Processing Record 520 of set 11 | halifax
# Processing Record 521 of set 11 | kununurra
# Processing Record 522 of set 11 | rawson
# Processing Record 523 of set 11 | saquena
# Processing Record 524 of set 11 | teonthar
# Processing Record 525 of set 11 | kavaratti
# Processing Record 526 of set 11 | ye
# City not found. Skipping ...
# Processing Record 527 of set 11 | tammisaari
# Processing Record 528 of set 11 | mercedes
# Processing Record 529 of set 11 | tsihombe
# City not found. Skipping ...
# Processing Record 530 of set 11 | hobyo
# Processing Record 531 of set 11 | trat
# Processing Record 532 of set 11 | nouadhibou
# Processing Record 533 of set 11 | santa isabel do rio negro
# Processing Record 534 of set 11 | arteaga
# Processing Record 535 of set 11 | akonolinga
# Processing Record 536 of set 11 | pasighat
# Processing Record 537 of set 11 | shibarghan
# City not found. Skipping ...
# Processing Record 538 of set 11 | keetmanshoop
# Processing Record 539 of set 11 | gombe
# Processing Record 540 of set 11 | el campo
# Processing Record 541 of set 11 | roald
# Processing Record 542 of set 11 | ambilobe
# Processing Record 543 of set 11 | knysna
# Processing Record 544 of set 11 | bago
# Processing Record 545 of set 11 | kozhva
# Processing Record 546 of set 11 | lukovetskiy
# Processing Record 547 of set 11 | fortuna
# Processing Record 548 of set 11 | zlobin
# Processing Record 549 of set 11 | wewak
# Processing Record 550 of set 11 | lodwar
# Processing Record 551 of set 11 | luebo
# Processing Record 552 of set 11 | matay
# Processing Record 553 of set 11 | iberia
# Processing Record 554 of set 11 | axim
# Processing Record 555 of set 11 | matamoros
# Processing Record 556 of set 11 | drayton valley
# Processing Record 557 of set 11 | linjiang
# Processing Record 558 of set 11 | paikuse
# Processing Record 559 of set 11 | charters towers
# Processing Record 560 of set 11 | conselheiro pena
# Processing Record 562 of set 12 | varkkallai
# Processing Record 563 of set 12 | riyadh
# Processing Record 564 of set 12 | skalistyy
# City not found. Skipping ...
# Processing Record 565 of set 12 | graaff-reinet
# Processing Record 566 of set 12 | kurayoshi
# Processing Record 567 of set 12 | beidao
# Processing Record 568 of set 12 | mbinga
# Processing Record 569 of set 12 | thyboron
# Processing Record 570 of set 12 | wilmington
# Processing Record 571 of set 12 | avera
# Processing Record 572 of set 12 | tomatlan
# Processing Record 573 of set 12 | lubbock
# Processing Record 574 of set 12 | brownsville
# Processing Record 575 of set 12 | huarmey
# Processing Record 576 of set 12 | ardesen
# Processing Record 577 of set 12 | mackay
# Processing Record 578 of set 12 | malwan
# City not found. Skipping ...
# Processing Record 579 of set 12 | tazmalt
# Processing Record 580 of set 12 | aswan
# Processing Record 581 of set 12 | qiqihar
# Processing Record 582 of set 12 | zhob
# Processing Record 583 of set 12 | sabang
# Processing Record 584 of set 12 | san ramon
# Processing Record 585 of set 12 | kamenskoye
# City not found. Skipping ...
# Processing Record 586 of set 12 | mount isa
# Processing Record 587 of set 12 | maniitsoq
# Processing Record 588 of set 12 | manzhouli
# Processing Record 589 of set 12 | tigil
# Processing Record 590 of set 12 | buchmany
# Processing Record 591 of set 12 | paracatu
# Processing Record 592 of set 12 | meadow lake
# Processing Record 593 of set 12 | eldorado
# Processing Record 594 of set 12 | mattru
# Processing Record 595 of set 12 | nyurba
# Processing Record 596 of set 12 | warwick
# Processing Record 597 of set 12 | camacha
# Processing Record 598 of set 12 | beloha
# Processing Record 599 of set 12 | iquique
# Processing Record 600 of set 12 | ban nahin
# Processing Record 601 of set 12 | evensk
# Processing Record 602 of set 12 | inirida
# Processing Record 603 of set 12 | talara
# Processing Record 604 of set 12 | ntcheu
# Processing Record 605 of set 12 | narsaq
# Processing Record 606 of set 12 | burns lake
# Processing Record 607 of set 12 | columbus
# Processing Record 608 of set 12 | kobryn
# Processing Record 609 of set 12 | shubarshi
# Processing Record 610 of set 12 | port hedland
# Processing Record 611 of set 12 | kamsack
# Processing Record 613 of set 13 | toftir
# City not found. Skipping ...
# Processing Record 614 of set 13 | burica
# City not found. Skipping ...
# Processing Record 615 of set 13 | codajas
# Processing Record 616 of set 13 | salinas
# Processing Record 617 of set 13 | the valley
# Processing Record 618 of set 13 | windham
# Processing Record 619 of set 13 | yamada
# Processing Record 620 of set 13 | macaboboni
# City not found. Skipping ...
# Processing Record 621 of set 13 | erdenet
# Processing Record 622 of set 13 | sogne
# Processing Record 623 of set 13 | tabatinga
# Processing Record 624 of set 13 | shagamu
# Processing Record 625 of set 13 | yinchuan
# Processing Record 626 of set 13 | pochinki
# Processing Record 627 of set 13 | kuito
# Processing Record 628 of set 13 | bima
# Processing Record 629 of set 13 | barawe
# City not found. Skipping ...
# Processing Record 630 of set 13 | liepaja
# Processing Record 631 of set 13 | hay river
# Processing Record 632 of set 13 | payo
# Processing Record 633 of set 13 | jacareacanga
# Processing Record 634 of set 13 | maicao
# Processing Record 635 of set 13 | paungde
# Processing Record 636 of set 13 | san bartolome de tirajana
# Processing Record 637 of set 13 | petropavlovsk-kamchatskiy
# Processing Record 638 of set 13 | whitianga
# Processing Record 639 of set 13 | linfen
# Processing Record 640 of set 13 | rawannawi
# City not found. Skipping ...
# Processing Record 641 of set 13 | nerchinskiy zavod
# Processing Record 642 of set 13 | karauzyak
# City not found. Skipping ...
# Processing Record 643 of set 13 | camocim
# Processing Record 644 of set 13 | roma
# Processing Record 645 of set 13 | kolokani
# Processing Record 646 of set 13 | nantucket
# Processing Record 647 of set 13 | sokolo
# Processing Record 648 of set 13 | sao jose da coroa grande
# Processing Record 649 of set 13 | vanavara
# Processing Record 650 of set 13 | huilong
# Processing Record 651 of set 13 | noumea
# Processing Record 652 of set 13 | longlac
# City not found. Skipping ...
# Processing Record 653 of set 13 | westport
# Processing Record 654 of set 13 | lehigh acres
# Processing Record 655 of set 13 | vanderhoof
# Processing Record 656 of set 13 | tual
# Processing Record 657 of set 13 | vao
# Processing Record 658 of set 13 | truro
# Processing Record 659 of set 13 | bilibino
# Processing Record 660 of set 13 | jining
# Processing Record 661 of set 13 | waw
# Processing Record 662 of set 13 | chipinge
# Processing Record 664 of set 14 | sioux lookout
# Processing Record 665 of set 14 | hengshan
# Processing Record 666 of set 14 | bijni
# Processing Record 667 of set 14 | bud
# Processing Record 668 of set 14 | sibolga
# Processing Record 669 of set 14 | bonthe
# Processing Record 670 of set 14 | celestun
# Processing Record 671 of set 14 | ust-kamchatsk
# City not found. Skipping ...
# Processing Record 672 of set 14 | hecun
# Processing Record 673 of set 14 | scarborough
# Processing Record 674 of set 14 | la romana
# Processing Record 675 of set 14 | kupang
# Processing Record 676 of set 14 | freeport
# Processing Record 677 of set 14 | komsomolskiy
# Processing Record 678 of set 14 | ossora
# Processing Record 679 of set 14 | laiwu
# Processing Record 680 of set 14 | metaxades
# Processing Record 681 of set 14 | baykalsk
# Processing Record 682 of set 14 | omboue
# Processing Record 683 of set 14 | inuvik
# Processing Record 684 of set 14 | lae
# Processing Record 685 of set 14 | oskemen
# Processing Record 686 of set 14 | ji-parana
# City not found. Skipping ...
# Processing Record 687 of set 14 | ostashkov
# Processing Record 688 of set 14 | pouembout
# Processing Record 689 of set 14 | soto la marina
# Processing Record 690 of set 14 | battle creek
# Processing Record 691 of set 14 | isangel
# Processing Record 692 of set 14 | mogadishu
# Processing Record 693 of set 14 | davila
# Processing Record 694 of set 14 | maragogi
# Processing Record 695 of set 14 | staszow
# Processing Record 696 of set 14 | lakhimpur
# Processing Record 697 of set 14 | ozgon
# City not found. Skipping ...
# Processing Record 698 of set 14 | labytnangi
# Processing Record 699 of set 14 | fort nelson
# Processing Record 700 of set 14 | concarneau
# Processing Record 701 of set 14 | varnavino
# Processing Record 702 of set 14 | tezu
# Processing Record 703 of set 14 | san jose de tarros
# Processing Record 704 of set 14 | meulaboh
# Processing Record 705 of set 14 | changping
# Processing Record 706 of set 14 | krasnik
# Processing Record 707 of set 14 | harindanga
# Processing Record 708 of set 14 | prainha
# Processing Record 709 of set 14 | rio gallegos
# Processing Record 710 of set 14 | batemans bay
# Processing Record 711 of set 14 | likasi
# Processing Record 712 of set 14 | fenoarivo
# Processing Record 713 of set 14 | puerto madero
# Processing Record 715 of set 15 | gushikawa
# Processing Record 716 of set 15 | san andres
# Processing Record 717 of set 15 | sola
# Processing Record 718 of set 15 | uvalde
# Processing Record 719 of set 15 | neuquen
# Processing Record 720 of set 15 | atar
# Processing Record 721 of set 15 | lewistown
# Processing Record 722 of set 15 | havre-saint-pierre
# Processing Record 723 of set 15 | borger
# Processing Record 724 of set 15 | havoysund
# Processing Record 725 of set 15 | nishihara
# Processing Record 726 of set 15 | grindavik
# Processing Record 727 of set 15 | altamira
# Processing Record 728 of set 15 | businga
# Processing Record 729 of set 15 | thunder bay
# Processing Record 730 of set 15 | limon
# Processing Record 731 of set 15 | vikhorevka
# Processing Record 732 of set 15 | bakel
# Processing Record 733 of set 15 | marzuq
# Processing Record 734 of set 15 | sabha
# Processing Record 735 of set 15 | champua
# Processing Record 736 of set 15 | yar-sale
# Processing Record 737 of set 15 | general pico
# Processing Record 738 of set 15 | khor
# Processing Record 739 of set 15 | birjand
# Processing Record 740 of set 15 | lincent
# Processing Record 741 of set 15 | hervey bay
# Processing Record 742 of set 15 | mutsamudu
# City not found. Skipping ...
# Processing Record 743 of set 15 | caceres
# Processing Record 744 of set 15 | picayune
# Processing Record 745 of set 15 | verkhoyansk
# Processing Record 746 of set 15 | sabya
# Processing Record 747 of set 15 | pilao arcado
# City not found. Skipping ...
# Processing Record 748 of set 15 | waseca
# Processing Record 749 of set 15 | breves
# Processing Record 750 of set 15 | kikwit
# Processing Record 751 of set 15 | pahrump
# Processing Record 752 of set 15 | leshukonskoye
# Processing Record 753 of set 15 | kaeo
# Processing Record 754 of set 15 | natitingou
# Processing Record 755 of set 15 | gimli
# Processing Record 756 of set 15 | bandundu
# Processing Record 757 of set 15 | belvidere
# Processing Record 758 of set 15 | chapais
# Processing Record 759 of set 15 | tigzirt
# Processing Record 760 of set 15 | shiyan
# Processing Record 761 of set 15 | urucurituba
# Processing Record 762 of set 15 | presidencia roque saenz pena
# Processing Record 763 of set 15 | ferai
# City not found. Skipping ...
# Processing Record 764 of set 15 | phangnga
# Processing Record 766 of set 16 | tevaitoa
# Processing Record 767 of set 16 | byron bay
# Processing Record 768 of set 16 | curuca
# Processing Record 769 of set 16 | aktau
# Processing Record 770 of set 16 | salinopolis
# ----------------------
# Data Retrieval Complete
# ----------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Humidity  Cloudiness  Wind Speed Country  \
# 0        Gat  31.6100   34.7642        24           7        4.45      IL
# 1     Barrow  71.2906 -156.7887        91           1        3.44      US
# 2  Jaguarari -10.2639  -40.1958        29           5        9.15      BR
# 3       Hilo  19.7297 -155.0900        60          40        5.75      US
# 4    Ushuaia -54.8000  -68.3000        67          75       20.71      AR
#
#                   Date  Max Temp      Current Description
# 0  2021-03-27 18:21:15     57.99                clear sky
# 1  2021-03-27 18:20:47    -16.60                clear sky
# 2  2021-03-27 18:23:48     89.13                clear sky
# 3  2021-03-27 18:20:54     73.40               light rain
# 4  2021-03-27 18:20:44     57.20  light intensity drizzle

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
